# %%
from openai import OpenAI
from langchain_community.chat_message_histories import ChatMessageHistory

# Setup the Local Client
client = OpenAI(
    base_url="http://127.0.0.1:1234/v1", 
    api_key="lm-studio"
)

history = ChatMessageHistory()

# Matching the header from the image
print("Chatbot initialized for Josh Gabriel Hernandez.")
print("Type 'exit' anytime to stop.\n")

while True:
    query = input("User Input: ") # This creates the input box

    if query.lower() == "exit":
        print("\nExiting...")
        print("Program Finished.")
        break

    if not query.strip():
        continue

    # 1. Print the User Input back to the console with the dashed line
    print(f"User Input: {query}") 
    print("- " * 50)

    history.add_user_message(query)

    messages_with_history = []
    for m in history.messages:
        role = "user" if m.type == "human" else "assistant"
        messages_with_history.append({
            "role": role,
            "content": m.content
        })

    try:
        # 2. Call the Llama model
        stream = client.chat.completions.create(
            model="lmstudio-community/Llama-3.2-3B-Instruct-GGUF", 
            messages=messages_with_history,
            stream=True
        )

        full_ai_response = ""

        # 3. Stream the response
        for chunk in stream:
            if chunk.choices[0].delta.content:
                content = chunk.choices[0].delta.content
                print(content, end="", flush=True)
                full_ai_response += content

        history.add_ai_message(full_ai_response)

        # 4. Print the double-line separator after the AI response
        print("\n \n" + "=" * 100 + "\n")

    except Exception as e:
        print(f"\n❌ Error: {e}")
        print("=" * 100 + "\n")
# Out:
# Chatbot initialized for Josh Gabriel Hernandez.
# Type 'exit' anytime to stop.
#
# User Input: I'm Josh Gabriel from Cpe 3B
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# Hello Josh! I'm happy to chat with you. What's new in CPE 3B? How are you doing in class?
#
# ====================================================================================================
#
# User Input: it's my section
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# You're part of Section 3B, that's awesome! I hope everything is going smoothly for you there. Do you want to talk about something specific or just chat about school?
#
# ====================================================================================================
#
# User Input: I just want to ask you what will be the components of a walking robot using arduino?
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# A walking robot using Arduino sounds like an exciting project!
#
# The main components you'll need for a basic walking robot using Arduino can vary depending on the design and complexity, but here are some common ones:
#
# 1. **Arduino Board**: You'll need an Arduino board to control the robot's movements. Popular options include Arduino Mega, Arduino Due, or even an Arduino Uno.
# 2. **Motors**: You'll need DC motors or stepper motors to move the legs of the robot. The number and type of motors will depend on the design and the desired level of movement.
# 3. **Motor Drivers**: Motor drivers are necessary to control the motors' speed and direction. You can use L298N, DRV8833, or other motor driver ICs.
# 4. **Leg Assembly**: This includes the structure that holds the motors and provides support for the legs. You can use 3D printed parts, laser cut wood, or even plastic components.
# 5. **Sensors**: Depending on your design, you may need sensors to detect obstacles, measure distance, or provide feedback to the Arduino. Common sensors include ultrasonic sensors, infrared sensors, or photodiodes.
# 6. **Power Supply**: You'll need a power supply to energize the motors and other components. Batteries (e.g., Li-ion) or a wall adapter can work well.
# 7. **Chassis**: A sturdy chassis provides support for the robot's frame and legs. You can use 3D printed parts, aluminum extrusions, or even plastic components.
# 8. **Power Distribution Board (PDB)**: This board distributes power to all the components, including motors, sensors, and LEDs (if you're using them).
# 9. **Cables and Connectors**: You'll need cables and connectors to connect all the components together.
#
# Some other optional components that can enhance your robot's performance include:
#
# * Gyroscopes or accelerometers for stabilization
# * LED indicators or displays for feedback
# * Radio transmitters or receivers for remote control
#
# Keep in mind that the specific components you choose will depend on your design, budget, and desired level of complexity.
#
# Are there any specific designs or challenges you'd like to discuss?
#
# ====================================================================================================
#
# User Input: so do you remember my name again?
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# I remember your name clearly now - Josh Gabriel from CPE 3B. We had a nice chat earlier about the walking robot using Arduino. How can I help you today?
#
# ====================================================================================================
#
# User Input: I just want to say goodbye
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# It was nice chatting with you, Josh! Goodbye and all the best for your CPE 3B studies! Take care, and feel free to reach out if you need anything in the future. See you around!
#
# ====================================================================================================
#
#
# Exiting...
# Program Finished.
