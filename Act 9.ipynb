# %%
import numpy as np
import matplotlib.pyplot as plt
import control as ctrl

# %%
# Define the transfer function of the system
num = [1,1]  # Numerator coefficients
den = [2,1,0]  # Denominator coefficients

# %%
G = ctrl.TransferFunction(num, den)
print("Transfer Function G(s):")
print(G)
# Out:
# Transfer Function G(s):
# <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#     s + 1
#   ---------
#   2 s^2 + s

# %%
#Step response
t, y = ctrl.step_response(G)
plt.figure()   
plt.plot(t, y)
plt.title('Step Response')
plt.xlabel('Time (s)')
plt.ylabel('Output')
plt.grid()
plt.show()

# %%
ctrl.pzmap(G, grid=True, title='Pole-Zero Map')
plt.show()
plt.figure(figsize=(8, 6))
ctrl.pzmap(sys, grid=True)
plt.title('Pole-Zero Map')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2 plt.show()
#       3 plt.figure(figsize=(8, 6))
# ----> 4 ctrl.pzmap(sys, grid=True)
#       5 plt.title('Pole-Zero Map')
#       6 plt.show()
#
# NameError: name 'sys' is not defined
